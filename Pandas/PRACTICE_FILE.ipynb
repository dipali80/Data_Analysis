# %%
import numpy as np
import pandas as pd

# %%
#Create a DataFrame from dictionary.

#Read a CSV file into DataFrame.

#Display first 5 and last 5 records.

#Find column names and data types.

#Select one column and multiple columns.

#Add a new column to DataFrame.

#Rename column names.

# %%
#Create a DataFrame from dictionary.

data = pd.DataFrame({"Name":["Dipali","soham","sangita","shankar"],
                    "Address" :["pune","mumbai","pune","mumbai"],
                    "Age":[20,17,40,50],
                    "Gender":["f","m","f","m"]})
data
# Out:
#       Name Address  Age Gender
# 0   Dipali    pune   20      f
# 1    soham  mumbai   17      m
# 2  sangita    pune   40      f
# 3  shankar  mumbai   50      m

# %%
#Read a CSV file into DataFrame.
data1 = pd.read_csv("DATAFRAMES/Fortune_10.csv")

# %%
#Display first 5 and last 5 records.
data1.head()
# Out:
#    ID Date             Name           Companies  Inception      Revenue  \
# 0   1  Yes          Lamtone          IT Service       2009  $11,757,018
# 1   2  Yes        Stripfind  Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation              Health       2012  $10,597,009
# 3   4  Yes         Mattouch          IT Service       2013  $14,026,934
# 4   5   No        Techdrill              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
data1.tail()
# Out:
#    ID Date            Name            Companies  Inception      Revenue  \
# 5   6  Yes        Techline               Health       2006  $13,898,119
# 6   7  Yes         Cityace               Health       2010   $9,254,614
# 7   8   No  Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes         Ganzlax           IT Service       2011  $14,001,180
# 9  10  Yes    Transtraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8  3,878,153 Dollars  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
#Find column names and data types.
data1.coulmns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16844\2883149155.py in ?()
#       1 #Find column names and data types.
# ----> 2 data1.coulmns
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'coulmns'
